# %% [markdown]
# #

# %% [markdown]
# ## Control Training
#
# Adding

# %%
import sequential_model as sequentialModel

# %%
sequentialModel.run_model("control", 10, 200, useContoursFiltering=False, useDataFiltering= False)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_8 (Conv2D)           (None, 64, 64, 32)        320
#
#  max_pooling2d_8 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 96)        6240
#
#  max_pooling2d_10 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 96)          9312
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 1536)              0
#
#  dense_4 (Dense)             (None, 512)               786944
#
#  activation_2 (Activation)   (None, 512)               0
#
#  dense_5 (Dense)             (None, 310)               159030
#
# ...
# Total params: 980,342
# Trainable params: 980,342
# ...

# %%
sequentialModel.run_model("control-with-kanji-filtering", 10, 200, useContoursFiltering=False, useDataFiltering= True)
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 92432
# amount of data after cleaning 85980
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 64, 64, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 96)        6240
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 96)          9312
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense (Dense)               (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("control", 10, 200, useContoursFiltering=True, useDataFiltering= False)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 64, 64, 32)        320
#
#  max_pooling2d_4 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 96)        6240
#
#  max_pooling2d_6 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 96)          9312
#
#  max_pooling2d_7 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1536)              0
#
#  dense_2 (Dense)             (None, 512)               786944
#
#  activation_1 (Activation)   (None, 512)               0
#
#  dense_3 (Dense)             (None, 309)               158517
#
# ...
# Total params: 979,829
# Trainable params: 979,829
# ...

# %%
sequentialModel.run_model("basic", 10, 200, useContoursFiltering=True, useDataFiltering= True)
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 64, 64, 32)        320
#
#  max_pooling2d_4 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 96)        6240
#
#  max_pooling2d_6 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 96)          9312
#
#  max_pooling2d_7 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1536)              0
#
#  dense_2 (Dense)             (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("basic2", 10, 200, useContoursFiltering=True, useDataFiltering= True, kernelsizes = [9, 5, 3, 1])
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_8 (Conv2D)           (None, 64, 64, 32)        2624
#
#  max_pooling2d_8 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 64)        51264
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 96)        55392
#
#  max_pooling2d_10 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 96)          9312
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 1536)              0
#
#  dense_4 (Dense)             (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("big_kernels", 10, 200, useContoursFiltering=True, useDataFiltering= True, kernelsizes = [9, 7, 5, 1])
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_12 (Conv2D)          (None, 64, 64, 32)        2624
#
#  max_pooling2d_12 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 64)        100416
#
#  max_pooling2d_13 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 96)        153696
#
#  max_pooling2d_14 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 96)          9312
#
#  max_pooling2d_15 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 1536)              0
#
#  dense_6 (Dense)             (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("not_as_big_kernels", 10, 200, useContoursFiltering=True, useDataFiltering= True, kernelsizes = [5, 3, 3, 1])
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_16 (Conv2D)          (None, 64, 64, 32)        832
#
#  max_pooling2d_16 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 64)        18496
#
#  max_pooling2d_17 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 96)        55392
#
#  max_pooling2d_18 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 8, 8, 96)          9312
#
#  max_pooling2d_19 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 1536)              0
#
#  dense_8 (Dense)             (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("not_as_big_kernels", 10, 200, useContoursFiltering=True, useDataFiltering= True, kernelsizes = [11, 9, 5, 1])
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_20 (Conv2D)          (None, 64, 64, 32)        3904
#
#  max_pooling2d_20 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 64)        165952
#
#  max_pooling2d_21 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 16, 16, 96)        153696
#
#  max_pooling2d_22 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 96)          9312
#
#  max_pooling2d_23 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 1536)              0
#
#  dense_10 (Dense)            (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("bigger_kernels_again", 10, 200,  kernelsizes = [15, 9, 5, 3])
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_24 (Conv2D)          (None, 64, 64, 32)        7232
#
#  max_pooling2d_24 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 32, 32, 64)        165952
#
#  max_pooling2d_25 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 16, 16, 96)        153696
#
#  max_pooling2d_26 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 8, 8, 96)          83040
#
#  max_pooling2d_27 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 1536)              0
#
#  dense_12 (Dense)            (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("basic", 10, 200, useContoursFiltering=True, useDataFiltering= True)

# %%
sequentialModel.run_model("8filters", 10, 200, filters = 8)

sequentialModel.run_model("16filters", 10, 200, filters = 16)

sequentialModel.run_model("32filters", 10, 200, filters = 32)

sequentialModel.run_model("64filters", 10, 200, filters = 64)
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 64, 64, 8)         80
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 16)        1168
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 24)        408
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 24)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 24)          600
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 24)         0
#  2D)
#
#  flatten (Flatten)           (None, 384)               0
#
#  dense (Dense)               (None, 512)               197120
#
# ...

# %%
sequentialModel.run_model("64filters", 10, 200, filters = 64)
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_16 (Conv2D)          (None, 64, 64, 64)        640
#
#  max_pooling2d_16 (MaxPoolin  (None, 32, 32, 64)       0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 128)       73856
#
#  max_pooling2d_17 (MaxPoolin  (None, 16, 16, 128)      0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 192)       24768
#
#  max_pooling2d_18 (MaxPoolin  (None, 8, 8, 192)        0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 8, 8, 192)         37056
#
#  max_pooling2d_19 (MaxPoolin  (None, 4, 4, 192)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 3072)              0
#
#  dense_8 (Dense)             (None, 512)               1573376
#
# ...

# %%
sequentialModel.run_model("higher_lr", 10, 200, useContoursFiltering=False, useDataFiltering= False)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 64, 64, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 96)        6240
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 96)          9312
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense (Dense)               (None, 512)               786944
#
#  activation (Activation)     (None, 512)               0
#
#  dense_1 (Dense)             (None, 310)               159030
#
# ...
# Total params: 980,342
# Trainable params: 980,342
# ...

# %%
sequentialModel.run_model("withdropout", 10, 200, useContoursFiltering=True, useDataFiltering= True, dropout = True)
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 64, 64, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 96)        6240
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 8, 8, 96)          0
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 96)          9312
#
# ...

# %%
sequentialModel.run_model("control-with-kanji-filtering", 10, 200, useContoursFiltering=True, useDataFiltering= True, activation="sigmoid")
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 64, 64, 32)        320
#
#  max_pooling2d_4 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 96)        6240
#
#  max_pooling2d_6 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 96)          9312
#
#  max_pooling2d_7 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1536)              0
#
#  dense_2 (Dense)             (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("control-with-kanji-filtering", 10, 200, useContoursFiltering=True, useDataFiltering= True, activation="softmax")
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_8 (Conv2D)           (None, 64, 64, 32)        320
#
#  max_pooling2d_8 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 96)        6240
#
#  max_pooling2d_10 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 96)          9312
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 1536)              0
#
#  dense_4 (Dense)             (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("control-with-kanji-filtering", 10, 200, useContoursFiltering=True, useDataFiltering= True, activation="relu")
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_12 (Conv2D)          (None, 64, 64, 32)        320
#
#  max_pooling2d_12 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 64)        18496
#
#  max_pooling2d_13 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 96)        6240
#
#  max_pooling2d_14 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 96)          9312
#
#  max_pooling2d_15 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 1536)              0
#
#  dense_6 (Dense)             (None, 512)               786944
#
# ...
