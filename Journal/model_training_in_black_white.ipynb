# %%
from modules import sequential_model as sequentialModel

# %%
sequentialModel.run_model("control-with-kanji-filtering_bw", 10, 200, use_contours_filtering=False, use_data_filtering= True, colors="BW")
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 92432
# amount of data after cleaning 85980
# turning images to bw
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 64, 64, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 96)        6240
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 96)          9312
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense (Dense)               (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("control_bw", 10, 200, use_contours_filtering=True, use_data_filtering= False, colors="BW")
# Out:
# turning images to bw
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_8 (Conv2D)           (None, 64, 64, 32)        320
#
#  max_pooling2d_8 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 96)        6240
#
#  max_pooling2d_10 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 96)          9312
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 1536)              0
#
#  dense_4 (Dense)             (None, 512)               786944
#
#  activation_2 (Activation)   (None, 512)               0
#
#  dense_5 (Dense)             (None, 309)               158517
#
# ...
# Total params: 979,829
# ...

# %%
sequentialModel.run_model("basic_bw", 10, 200,  colors="BW")
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# turning images to bw
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_12 (Conv2D)          (None, 64, 64, 32)        320
#
#  max_pooling2d_12 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 64)        18496
#
#  max_pooling2d_13 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 96)        6240
#
#  max_pooling2d_14 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 96)          9312
#
#  max_pooling2d_15 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 1536)              0
#
#  dense_6 (Dense)             (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("basic2_bw", 10, 200, kernel_sizes = [9, 5, 3, 1], colors="BW")
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# turning images to bw
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_16 (Conv2D)          (None, 64, 64, 32)        2624
#
#  max_pooling2d_16 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 64)        51264
#
#  max_pooling2d_17 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 96)        55392
#
#  max_pooling2d_18 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 8, 8, 96)          9312
#
#  max_pooling2d_19 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 1536)              0
#
#  dense_8 (Dense)             (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("big_kernels_bw", 10, 200,  kernel_sizes = [9, 7, 5, 1], colors="BW")
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# turning images to bw
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_20 (Conv2D)          (None, 64, 64, 32)        2624
#
#  max_pooling2d_20 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 32, 32, 64)        100416
#
#  max_pooling2d_21 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 16, 16, 96)        153696
#
#  max_pooling2d_22 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 8, 8, 96)          9312
#
#  max_pooling2d_23 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 1536)              0
#
#  dense_10 (Dense)            (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("not_as_big_kernels_bw", 10, 200,  kernel_sizes = [5, 3, 3, 1], colors="BW")
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# turning images to bw
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 64, 64, 32)        832
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 96)        55392
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 96)          9312
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense (Dense)               (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("not_as_big_kernels_bw", 10, 200,  kernel_sizes = [11, 9, 5, 1], colors="BW")
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# turning images to bw
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 64, 64, 32)        3904
#
#  max_pooling2d_4 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)        165952
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 96)        153696
#
#  max_pooling2d_6 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 96)          9312
#
#  max_pooling2d_7 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1536)              0
#
#  dense_2 (Dense)             (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("bigger_kernels_again_bw", 10, 200,  kernel_sizes = [15, 9, 5, 3], colors="BW")
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# turning images to bw
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_8 (Conv2D)           (None, 64, 64, 32)        7232
#
#  max_pooling2d_8 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 64)        165952
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 96)        153696
#
#  max_pooling2d_10 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 96)          83040
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 1536)              0
#
#  dense_4 (Dense)             (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("8filters_bw", 10, 200, filters = 8, colors="BW")

sequentialModel.run_model("16filters_bw", 10, 200, filters = 16 , colors="BW")

sequentialModel.run_model("32filters_bw", 10, 200, filters = 32 , colors="BW")

sequentialModel.run_model("64filters_bw", 10, 200, filters = 64 , colors="BW")

# %%
sequentialModel.run_model("64filters_bw", 10, 200, filters = 64, colors="BW")

# %%
sequentialModel.run_model("higher_lr_bw", 10, 200, use_contours_filtering=False, use_data_filtering= False, colors= "BW")

# %%
sequentialModel.run_model("withdropout_bw",20, 200,  dropout = 0.2, learning_rate=0.01,  colors="BW")
# Out:
# turning images to bw
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 64, 64, 32)        320
#
#  max_pooling2d_4 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 32, 32, 32)        0
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 96)        6240
#
#  max_pooling2d_6 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  dropout_6 (Dropout)         (None, 8, 8, 96)          0
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 96)          9312
#
#  max_pooling2d_7 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1536)              0
#
# ...

# %%
sequentialModel.run_model("withdropout_bw",20, 200,  dropout = 0.2, learning_rate=0.001,  colors="BW")
# Out:
# 318/318 [==============================] - 156s 492ms/step - loss: 1.6965 - accuracy: 0.5940 - val_loss: 0.8991 - val_accuracy: 0.7961
# Epoch 3/20
# 318/318 [==============================] - 107s 336ms/step - loss: 1.1650 - accuracy: 0.7067 - val_loss: 0.6454 - val_accuracy: 0.8497
# Epoch 4/20
# 318/318 [==============================] - 104s 328ms/step - loss: 0.9375 - accuracy: 0.7587 - val_loss: 0.5450 - val_accuracy: 0.8678
# Epoch 5/20
# 318/318 [==============================] - 104s 328ms/step - loss: 0.7954 - accuracy: 0.7919 - val_loss: 0.4607 - val_accuracy: 0.8865
# Epoch 6/20
# 318/318 [==============================] - 103s 325ms/step - loss: 0.7070 - accuracy: 0.8119 - val_loss: 0.4239 - val_accuracy: 0.8966
# Epoch 7/20
# 318/318 [==============================] - 104s 326ms/step - loss: 0.6368 - accuracy: 0.8312 - val_loss: 0.3757 - val_accuracy: 0.9084
# Epoch 8/20
# ...

# %%
sequentialModel.run_model("withdropout_bw",20, 200,  dropout = 0.1, learning_rate=0.001,  colors="BW")
# Out:
# turning images to bw
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_12 (Conv2D)          (None, 64, 64, 32)        320
#
#  max_pooling2d_12 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 32, 32, 32)        0
#
#  conv2d_13 (Conv2D)          (None, 32, 32, 64)        18496
#
#  max_pooling2d_13 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 16, 16, 64)        0
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 96)        6240
#
#  max_pooling2d_14 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 8, 8, 96)          0
#
#  conv2d_15 (Conv2D)          (None, 8, 8, 96)          9312
#
#  max_pooling2d_15 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 1536)              0
#
# ...

# %%
sequentialModel.run_model("sequential_model_bw", 4, 200,  kernel_sizes = [9, 7, 5, 1], colors="BW")
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 91375
# amount of data after cleaning 84965
# turning images to bw
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 64, 64, 32)        2624
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        100416
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 96)        153696
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 96)          9312
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense (Dense)               (None, 512)               786944
#
# ...

# %%
sequentialModel.run_model("withdropout_and_changing_bw", 30, 200,  dropout = 0.2, learning_rate=0.002, colors = "bw" )
# Out:
# turning images to bw
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 64, 64, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 96)        6240
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 8, 8, 96)          0
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 96)          9312
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  flatten (Flatten)           (None, 1536)              0
#
# ...

# %%
sequentialModel.run_model("withdropout_and_larger_kernel_bw", 30, 200,  dropout = 0.2, learning_rate=0.002, colors = "bw", kernel_sizes = [9, 7, 5, 1] )
# Out:
# turning images to bw
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_8 (Conv2D)           (None, 64, 64, 32)        2624
#
#  max_pooling2d_8 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  dropout_8 (Dropout)         (None, 32, 32, 32)        0
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 64)        100416
#
#  max_pooling2d_9 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_9 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 96)        153696
#
#  max_pooling2d_10 (MaxPoolin  (None, 8, 8, 96)         0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 8, 8, 96)          0
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 96)          9312
#
#  max_pooling2d_11 (MaxPoolin  (None, 4, 4, 96)         0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 1536)              0
#
# ...
