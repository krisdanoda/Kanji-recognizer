# %%
import sequentialModel as sequentialModel
# Out:
# 2023-05-22 19:44:47.291467: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-22 19:44:47.601302: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-05-22 19:44:47.601327: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-05-22 19:44:48.525987: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-05-22 19:44:48.526121: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-05-22 19:44:48.526132: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
sequentialModel.run_model("_control", 5, 200, useContoursFiltering=True, useDataFiltering= True)
# Out:
# amount of kanji before cleaning 3832
# amount of kanji after cleaning 1947
# amount of data before cleaning 90502
# amount of data after cleaning 84150
# 2023-05-22 19:45:05.960501: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib/python3.10/site-packages/cv2/../../lib64:
# 2023-05-22 19:45:05.960661: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-05-22 19:45:05.960749: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (a475452ce5ea): /proc/driver/nvidia/version does not exist
# 2023-05-22 19:45:05.961155: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 96)        6240
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 96)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 96)          9312
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 96)         0
#  2D)
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense (Dense)               (None, 512)               786944
#
#  activation (Activation)     (None, 512)               0
#
#  dense_1 (Dense)             (None, 294)               150822
#
# =================================================================
# Total params: 972,134
# Trainable params: 972,134
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 2023-05-22 19:45:06.987220: W tensorflow/tsl/framework/cpu_allocator_impl.cc:82] Allocation of 1034027008 exceeds 10% of free system memory.
# 315/315 [==============================] - 201s 633ms/step - loss: 4.3664 - accuracy: 0.1831 - val_loss: 2.9966 - val_accuracy: 0.3705
# Epoch 2/5
# 315/315 [==============================] - 190s 604ms/step - loss: 2.3137 - accuracy: 0.5022 - val_loss: 1.8079 - val_accuracy: 0.5934
# Epoch 3/5
# 315/315 [==============================] - 187s 593ms/step - loss: 1.4757 - accuracy: 0.6619 - val_loss: 1.3084 - val_accuracy: 0.6946
# Epoch 4/5
# 315/315 [==============================] - 190s 604ms/step - loss: 1.0821 - accuracy: 0.7439 - val_loss: 1.0575 - val_accuracy: 0.7504
# Epoch 5/5
# 315/315 [==============================] - 201s 638ms/step - loss: 0.8639 - accuracy: 0.7928 - val_loss: 0.9123 - val_accuracy: 0.7808
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models/_control/assets
# INFO:tensorflow:Assets written to: models/_control/assets
